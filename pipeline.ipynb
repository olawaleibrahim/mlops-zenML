# %%
from typing_extensions import Annotated  # or `from typing import Annotated on Python 3.9+
from typing import Tuple
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.base import ClassifierMixin
from sklearn.svm import SVC

from zenml import pipeline, step


import logging

@step
def training_data_loader() -> Tuple[
    Annotated[pd.DataFrame, "X_train"],
    Annotated[pd.DataFrame, "X_test"],
    Annotated[pd.Series, "y_train"],
    Annotated[pd.Series, "y_test"],
]:
    """Load the iris dataset as a tuple of Pandas DataFrame / Series."""
    logging.info("Loading iris...")
    iris = load_iris(as_frame=True)
    logging.info("Splitting train and test...")
    X_train, X_test, y_train, y_test = train_test_split(
        iris.data, iris.target, test_size=0.2, shuffle=True, random_state=42
    )
    return X_train, X_test, y_train, y_test


@step(enable_cache=False)
def svc_trainer(
        X_train: pd.DataFrame,
        y_train: pd.Series,
        gamma: float = 0.001,
) -> Tuple[
    Annotated[ClassifierMixin, "trained_model"],
    Annotated[float, "training_acc"],
]:
    """Train a sklearn SVC classifier."""

    model = SVC(gamma=gamma)
    model.fit(X_train.to_numpy(), y_train.to_numpy())

    train_acc = model.score(X_train.to_numpy(), y_train.to_numpy())
    print(f"Train accuracy: {train_acc}")

    return model, train_acc


@step
def digits_data_loader() -> Tuple[
    Annotated[pd.DataFrame, "X_train"],
    Annotated[pd.DataFrame, "X_test"],
    Annotated[pd.Series, "y_train"],
    Annotated[pd.Series, "y_test"],
]:
    """Loads the digits dataset and splits it into train and test data."""
    # Load data from the digits dataset
    digits = load_digits(as_frame=True)
    # Split into datasets
    X_train, X_test, y_train, y_test = train_test_split(
        digits.data, digits.target, test_size=0.2, shuffle=True
    )
    return X_train, X_test, y_train, y_test


@pipeline
def first_pipeline(gamma: float = 0.002):
    X_train, X_test, y_train, y_test = digits_data_loader()
    svc_trainer(gamma=gamma, X_train=X_train, y_train=y_train)


@pipeline
def first_pipeline(gamma: float = 0.002):
    X_train, X_test, y_train, y_test = training_data_loader()
    svc_trainer(gamma=gamma, X_train=X_train, y_train=y_train)

# %%
if __name__ == "__main__":
    first_pipeline = first_pipeline.with_options( enable_cache=False)
    first_pipeline()
# Out:
# Initiating a new run for the pipeline: first_pipeline.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_164215/3758811578.py:3 in <module>                                                │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_164215/3758811578.py'                       │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/new/pipel │
# │ ines/pipeline.py:1225 in __call__                                                                │
# │                                                                                                  │
# │   1222 │   │   │   return self.entrypoint(*args, **kwargs)                                       │
# │   1223 │   │                                                                                     │
# │   1224 │   │   self.prepare(*args, **kwargs)                                                     │
# │ ❱ 1225 │   │   return self._run(**self._run_args)                                                │
# │   1226 │                                                                                         │
# │   1227 │   def _call_entrypoint(self, *args: Any, **kwargs: Any) -> None:                        │
# │   1228 │   │   """Calls the pipeline entrypoint function with the given arguments.               │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/new/pipel │
# │ ines/pipeline.py:519 in _run                                                                     │
# │                                                                                                  │
# │    516 │   │   with event_handler(                                                               │
# │    517 │   │   │   event=AnalyticsEvent.RUN_PIPELINE, v2=True                                    │
# │    518 │   │   ) as analytics_handler:                                                           │
# │ ❱  519 │   │   │   deployment, pipeline_spec, schedule, build = self._compile(                   │
# │    520 │   │   │   │   config_path=config_path,                                                  │
# │    521 │   │   │   │   run_name=run_name,                                                        │
# │    522 │   │   │   │   enable_cache=enable_cache,                                                │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/new/pipel │
# │ ines/pipeline.py:917 in _compile                                                                 │
# │                                                                                                  │
# │    914 │   │                                                                                     │
# │    915 │   │   deployment, pipeline_spec = Compiler().compile(                                   │
# │    916 │   │   │   pipeline=self,                                                                │
# │ ❱  917 │   │   │   stack=Client().active_stack,                                                  │
# │    918 │   │   │   run_configuration=run_config,                                                 │
# │    919 │   │   )                                                                                 │
# │    920                                                                                           │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/client.py │
# │ :1560 in active_stack                                                                            │
# │                                                                                                  │
# │   1557 │   │   """                                                                               │
# │   1558 │   │   from zenml.stack.stack import Stack                                               │
# │   1559 │   │                                                                                     │
# │ ❱ 1560 │   │   return Stack.from_model(self.active_stack_model)                                  │
# │   1561 │                                                                                         │
# │   1562 │   def get_stack(                                                                        │
# │   1563 │   │   self,                                                                             │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/stack/sta │
# │ ck.py:151 in from_model                                                                          │
# │                                                                                                  │
# │    148 │   │   """                                                                               │
# │    149 │   │   from zenml.stack import StackComponent                                            │
# │    150 │   │                                                                                     │
# │ ❱  151 │   │   stack_components = {                                                              │
# │    152 │   │   │   type_: StackComponent.from_model(model[0])                                    │
# │    153 │   │   │   for type_, model in stack_model.components.items()                            │
# │    154 │   │   }                                                                                 │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/stack/sta │
# │ ck.py:152 in <dictcomp>                                                                          │
# │                                                                                                  │
# │    149 │   │   from zenml.stack import StackComponent                                            │
# │    150 │   │                                                                                     │
# │    151 │   │   stack_components = {                                                              │
# │ ❱  152 │   │   │   type_: StackComponent.from_model(model[0])                                    │
# │    153 │   │   │   for type_, model in stack_model.components.items()                            │
# │    154 │   │   }                                                                                 │
# │    155 │   │   return Stack.from_components(                                                     │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/stack/sta │
# │ ck_component.py:391 in from_model                                                                │
# │                                                                                                  │
# │   388 │   │   try:                                                                               │
# │   389 │   │   │   from zenml.stack import Flavor                                                 │
# │   390 │   │   │                                                                                  │
# │ ❱ 391 │   │   │   flavor = Flavor.from_model(flavor_model)                                       │
# │   392 │   │   except (ModuleNotFoundError, ImportError, NotImplementedError) as err:             │
# │   393 │   │   │   raise ImportError(                                                             │
# │   394 │   │   │   │   f"Couldn't import flavor {flavor_model.name}: {err}"                       │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/stack/fla │
# │ vor.py:132 in from_model                                                                         │
# │                                                                                                  │
# │   129 │   │   Returns:                                                                           │
# │   130 │   │   │   The loaded flavor.                                                             │
# │   131 │   │   """                                                                                │
# │ ❱ 132 │   │   flavor = source_utils.load(flavor_model.source)()                                  │
# │   133 │   │   return cast(Flavor, flavor)                                                        │
# │   134 │                                                                                          │
# │   135 │   def to_model(                                                                          │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/utils/sou │
# │ rce_utils.py:93 in load                                                                          │
# │                                                                                                  │
# │    90 │   elif source.type in {SourceType.USER, SourceType.UNKNOWN}:                             │
# │    91 │   │   # Unknown source might also refer to a user file, include source                   │
# │    92 │   │   # root in python path just to be sure                                              │
# │ ❱  93 │   │   import_root = get_source_root()                                                    │
# │    94 │                                                                                          │
# │    95 │   module = _load_module(module_name=source.module, import_root=import_root)              │
# │    96                                                                                            │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/utils/sou │
# │ rce_utils.py:229 in get_source_root                                                              │
# │                                                                                                  │
# │   226 │   │   )                                                                                  │
# │   227 │                                                                                          │
# │   228 │   if not hasattr(main_module, "__file__") or not main_module.__file__:                   │
# │ ❱ 229 │   │   raise RuntimeError(                                                                │
# │   230 │   │   │   "Unable to determine source root because the main module does not "            │
# │   231 │   │   │   "have an associated file. This could be because you're running in "            │
# │   232 │   │   │   "an interactive Python environment."                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Unable to determine source root because the main module does not have an associated file. This could
# be because you're running in an interactive Python environment.

# %%
from zenml.client import Client

pipeline_model = Client().get_pipeline("first_pipeline")

# %%
pipeline_model
# Out:
# PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>])

# %%
pipelines = Client().list_pipelines()

# %%
pipelines
# Out:
# Page(index=1, max_size=50, total_pages=1, total=4, items=[PipelineResponseModel(id=UUID('96f88f65-e0e9-4d5c-abd5-0a14bfeb727c'), created=datetime.datetime(2023, 7, 22, 15, 49, 28, 430409), updated=datetime.datetime(2023, 7, 22, 15, 49, 28, 430411), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='my_pipeline', version='1', version_hash='63a1c9729b32d38ed4753b94039302ab', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='run', attribute='my_pipeline', type=<SourceType.USER: 'user'>), parameters={}, steps=[StepSpec(source=Source(module='run', attribute='step_1', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='step_1'), StepSpec(source=Source(module='run', attribute='step_2', type=<SourceType.USER: 'user'>), upstream_steps=['step_1'], inputs={'input_two': InputSpec(step_name='step_1', output_name='output')}, pipeline_parameter_name='step_2')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), PipelineResponseModel(id=UUID('ac2b4629-76de-44b3-bdeb-a9639e4236e9'), created=datetime.datetime(2023, 7, 22, 16, 25, 12, 878418), updated=datetime.datetime(2023, 7, 22, 16, 25, 12, 878420), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='1', version_hash='870997c189c817025b557ff8670f2526', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.0015}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.FAILED: 'failed'>, <ExecutionStatus.FAILED: 'failed'>]), PipelineResponseModel(id=UUID('81252454-78f0-4aec-8d87-34e85f1c308b'), created=datetime.datetime(2023, 7, 22, 16, 43, 40, 248376), updated=datetime.datetime(2023, 7, 22, 16, 43, 40, 248377), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', v ...

# %%
pipeline_model.runs
# Out:
# [PipelineRunResponseModel(id=UUID('1dafe204-c206-454e-9130-fc925a7ed72a'), created=datetime.datetime(2023, 7, 23, 10, 9, 5, 948570), updated=datetime.datetime(2023, 7, 23, 10, 9, 7, 762275), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline-2023_07_23-10_09_05_938144', orchestrator_run_id='ee63c951-6355-410e-ae00-3f5008ec1311', schedule_id=None, enable_cache=None, start_time=datetime.datetime(2023, 7, 23, 10, 9, 5, 941776), end_time=datetime.datetime(2023, 7, 23, 10, 9, 7, 754033), status=<ExecutionStatus.COMPLETED: 'completed'>, config=PipelineConfiguration(enable_cache=False, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, name='first_pipeline'), num_steps=2, client_version='0.42.1', server_version='0.42.1', client_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, orchestrator_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, pipeline=PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), stack=StackResponseModel(id=UUID('36c4c60b-99a0-4340-a0f7-b80428adcbce'), created=datetime.datetime(2023, 7, 22, 15, 49, 22, 293300), updated=datetime.datetime(2023, 7, 22, 15, 49, 22, 293302), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel ...
#  PipelineRunResponseModel(id=UUID('414bd8e2-7aa0-43f5-b41e-cf52e69f5f64'), created=datetime.datetime(2023, 7, 23, 10, 8, 21, 911088), updated=datetime.datetime(2023, 7, 23, 10, 8, 23, 746304), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline-2023_07_23-10_08_21_820936', orchestrator_run_id='f0a8ae6d-6a43-4f29-ba3b-99172c2e214a', schedule_id=None, enable_cache=None, start_time=datetime.datetime(2023, 7, 23, 10, 8, 21, 903690), end_time=datetime.datetime(2023, 7, 23, 10, 8, 23, 737436), status=<ExecutionStatus.COMPLETED: 'completed'>, config=PipelineConfiguration(enable_cache=False, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, name='first_pipeline'), num_steps=2, client_version='0.42.1', server_version='0.42.1', client_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, orchestrator_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, pipeline=PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), stack=StackResponseModel(id=UUID('36c4c60b-99a0-4340-a0f7-b80428adcbce'), created=datetime.datetime(2023, 7, 22, 15, 49, 22, 293300), updated=datetime.datetime(2023, 7, 22, 15, 49, 22, 293302), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseM ...
#  PipelineRunResponseModel(id=UUID('d7553523-2bdf-4097-bfa7-0fd831b796aa'), created=datetime.datetime(2023, 7, 23, 10, 7, 45, 692726), updated=datetime.datetime(2023, 7, 23, 10, 7, 47, 543761), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline-2023_07_23-10_07_45_683021', orchestrator_run_id='67264c0b-03dc-4d37-93fb-2429be67ea72', schedule_id=None, enable_cache=None, start_time=datetime.datetime(2023, 7, 23, 10, 7, 45, 685981), end_time=datetime.datetime(2023, 7, 23, 10, 7, 47, 537948), status=<ExecutionStatus.COMPLETED: 'completed'>, config=PipelineConfiguration(enable_cache=False, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, name='first_pipeline'), num_steps=2, client_version='0.42.1', server_version='0.42.1', client_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, orchestrator_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, pipeline=PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), stack=StackResponseModel(id=UUID('36c4c60b-99a0-4340-a0f7-b80428adcbce'), created=datetime.datetime(2023, 7, 22, 15, 49, 22, 293300), updated=datetime.datetime(2023, 7, 22, 15, 49, 22, 293302), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseM ...
#  PipelineRunResponseModel(id=UUID('9b4ad01a-8e13-44ef-a2c1-7babdddf0b59'), created=datetime.datetime(2023, 7, 23, 10, 7, 36, 247033), updated=datetime.datetime(2023, 7, 23, 10, 7, 38, 33492), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline-2023_07_23-10_07_36_236902', orchestrator_run_id='f3a6b33c-a57a-40c0-8326-34e21073787f', schedule_id=None, enable_cache=None, start_time=datetime.datetime(2023, 7, 23, 10, 7, 36, 240197), end_time=datetime.datetime(2023, 7, 23, 10, 7, 38, 25019), status=<ExecutionStatus.COMPLETED: 'completed'>, config=PipelineConfiguration(enable_cache=False, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, name='first_pipeline'), num_steps=2, client_version='0.42.1', server_version='0.42.1', client_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, orchestrator_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, pipeline=PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), stack=StackResponseModel(id=UUID('36c4c60b-99a0-4340-a0f7-b80428adcbce'), created=datetime.datetime(2023, 7, 22, 15, 49, 22, 293300), updated=datetime.datetime(2023, 7, 22, 15, 49, 22, 293302), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseMod ...
#  PipelineRunResponseModel(id=UUID('21052de4-5a89-4566-990c-898b6fa0c640'), created=datetime.datetime(2023, 7, 23, 10, 6, 29, 839116), updated=datetime.datetime(2023, 7, 23, 10, 6, 30, 596176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline-2023_07_23-10_06_29_829917', orchestrator_run_id='ef1a20e3-2b6a-440c-addc-23f2d5793f8d', schedule_id=None, enable_cache=None, start_time=datetime.datetime(2023, 7, 23, 10, 6, 29, 832531), end_time=datetime.datetime(2023, 7, 23, 10, 6, 30, 590930), status=<ExecutionStatus.COMPLETED: 'completed'>, config=PipelineConfiguration(enable_cache=None, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, name='first_pipeline'), num_steps=2, client_version='0.42.1', server_version='0.42.1', client_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, orchestrator_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, pipeline=PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), stack=StackResponseModel(id=UUID('36c4c60b-99a0-4340-a0f7-b80428adcbce'), created=datetime.datetime(2023, 7, 22, 15, 49, 22, 293300), updated=datetime.datetime(2023, 7, 22, 15, 49, 22, 293302), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseMo ...
#  PipelineRunResponseModel(id=UUID('686b5693-8c6a-4d6e-8532-20d9f4ed71df'), created=datetime.datetime(2023, 7, 23, 10, 5, 57, 277875), updated=datetime.datetime(2023, 7, 23, 10, 5, 58, 44425), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline-2023_07_23-10_05_57_269027', orchestrator_run_id='2e53f0a2-219a-4ebc-b660-408b236fc7e2', schedule_id=None, enable_cache=None, start_time=datetime.datetime(2023, 7, 23, 10, 5, 57, 271576), end_time=datetime.datetime(2023, 7, 23, 10, 5, 58, 39193), status=<ExecutionStatus.COMPLETED: 'completed'>, config=PipelineConfiguration(enable_cache=None, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, name='first_pipeline'), num_steps=2, client_version='0.42.1', server_version='0.42.1', client_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, orchestrator_environment={'environment': 'native', 'os': 'linux', 'linux_distro': 'ubuntu', 'linux_distro_like': 'debian', 'linux_distro_version': '20.04', 'python_version': '3.9.12'}, pipeline=PipelineResponseModel(id=UUID('821b24df-d929-433f-bb3d-89c61212bc24'), created=datetime.datetime(2023, 7, 23, 10, 5, 56, 944174), updated=datetime.datetime(2023, 7, 23, 10, 5, 56, 944176), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='first_pipeline', version='3', version_hash='1aeab08b326261b239b5496aacf3580e', docstring=None, spec=PipelineSpec(version='0.4', source=Source(module='pipeline', attribute='first_pipeline', type=<SourceType.USER: 'user'>), parameters={'gamma': 0.002}, steps=[StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer')]), status=[<ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>, <ExecutionStatus.COMPLETED: 'completed'>]), stack=StackResponseModel(id=UUID('36c4c60b-99a0-4340-a0f7-b80428adcbce'), created=datetime.datetime(2023, 7, 22, 15, 49, 22, 293300), updated=datetime.datetime(2023, 7, 22, 15, 49, 22, 293302), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=None, roles=None, email=None), workspace=WorkspaceResponseMode ...

# %%
pipeline_model.runs[0].steps
# Out:
# {'training_data_loader': StepRunResponseModel(id=UUID('4e1a0d21-03e8-4e73-9cba-23773dd4cb14'), created=datetime.datetime(2023, 7, 23, 10, 9, 5, 987018), updated=datetime.datetime(2023, 7, 23, 10, 9, 7, 78022), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='training_data_loader', config=StepConfiguration(name='training_data_loader', enable_cache=None, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, step_operator=None, experiment_tracker=None, parameters={}, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, outputs={'X_test': ArtifactConfiguration(materializer_source=(Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>),), default_materializer_source=None), 'X_train': ArtifactConfiguration(materializer_source=(Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>),), default_materializer_source=None), 'y_test': ArtifactConfiguration(materializer_source=(Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>),), default_materializer_source=None), 'y_train': ArtifactConfiguration(materializer_source=(Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>),), default_materializer_source=None)}, caching_parameters={'X_test_materializer_source': '4bb513c4edcb604f92c94074879d89f1', 'X_train_materializer_source': '4bb513c4edcb604f92c94074879d89f1', 'step_source': 'cee8644cb7dac77b24ad45364f344e0b37a2b23bfaece05d198b9f5bf988935b', 'y_test_materializer_source': '4bb513c4edcb604f92c94074879d89f1', 'y_train_materializer_source': '4bb513c4edcb604f92c94074879d89f1'}, external_input_artifacts={}), spec=StepSpec(source=Source(module='pipeline', attribute='training_data_loader', type=<SourceType.USER: 'user'>), upstream_steps=[], inputs={}, pipeline_parameter_name='training_data_loader'), pipeline_run_id=UUID('1dafe204-c206-454e-9130-fc925a7ed72a'), original_step_run_id=None, status=<ExecutionStatus.COMPLETED: 'completed'>, parent_step_ids=[], cache_key='d0b286222ee592f4aad1c75cd48fa957', docstring='Load the iris dataset as a tuple of Pandas DataFrame / Series.', source_code='@step\ndef training_data_loader() -> Tuple[\n    Annotated[pd.DataFrame, "X_train"],\n    Annotated[pd.DataFrame, "X_test"],\n    Annotated[pd.Series, "y_train"],\n    Annotated[pd.Series, "y_test"],\n]:\n    """Load the iris dataset as a tuple of Pandas DataFrame / Series."""\n    logging.info("Loading iris...")\n    iris = load_iris(as_frame=True)\n    logging.info("Splitting train and test...")\n    X_train, X_test, y_train, y_test = train_test_split(\n        iris.data, iris.target, test_size=0.2, shuffle=True, random_state=42\n    )\n    return X_train, X_test, y_train, y_test\n', start_time=datetime.datetime(2023, 7, 23, 10, 9, 5, 970987), end_time=datetime.datetime(2023, 7, 23, 10, 9, 7, 73387), inputs={}, outputs={'y_test': ArtifactResponseModel(id=UUID('10cde501-15fe-4411-b031-2b8c8031aaa7'), crea ...
#  'svc_trainer': StepRunResponseModel(id=UUID('3c73cf52-1396-47cb-9854-f7332b5f764c'), created=datetime.datetime(2023, 7, 23, 10, 9, 7, 259230), updated=datetime.datetime(2023, 7, 23, 10, 9, 7, 663936), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='svc_trainer', config=StepConfiguration(name='svc_trainer', enable_cache=False, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, step_operator=None, experiment_tracker=None, parameters={'gamma': 0.002}, settings={}, extra={}, failure_hook_source=None, success_hook_source=None, outputs={'trained_model': ArtifactConfiguration(materializer_source=(Source(module='zenml.integrations.sklearn.materializers.sklearn_materializer', attribute='SklearnMaterializer', type=<SourceType.INTERNAL: 'internal'>),), default_materializer_source=None), 'training_acc': ArtifactConfiguration(materializer_source=(Source(module='zenml.materializers.built_in_materializer', attribute='BuiltInMaterializer', type=<SourceType.INTERNAL: 'internal'>),), default_materializer_source=None)}, caching_parameters={'step_source': '727ed77ae38fb1808c74e3b8046b467f51cdaf137688d320aba59a941d170040', 'trained_model_materializer_source': '490884ba8c05400623df4bf491f04f0e', 'training_acc_materializer_source': 'df6827490c847695b5a20ef7d1aee23d'}, external_input_artifacts={}), spec=StepSpec(source=Source(module='pipeline', attribute='svc_trainer', type=<SourceType.USER: 'user'>), upstream_steps=['training_data_loader'], inputs={'X_train': InputSpec(step_name='training_data_loader', output_name='X_train'), 'y_train': InputSpec(step_name='training_data_loader', output_name='y_train')}, pipeline_parameter_name='svc_trainer'), pipeline_run_id=UUID('1dafe204-c206-454e-9130-fc925a7ed72a'), original_step_run_id=None, status=<ExecutionStatus.COMPLETED: 'completed'>, parent_step_ids=[UUID('4e1a0d21-03e8-4e73-9cba-23773dd4cb14')], cache_key='e38d26ab440a0372be8f3bd0e78c31be', docstring='Train a sklearn SVC classifier.', source_code='@step(enable_cache=False)\ndef svc_trainer(\n        X_train: pd.DataFrame,\n        y_train: pd.Series,\n        gamma: float = 0.001,\n) -> Tuple[\n    Annotated[ClassifierMixin, "trained_model"],\n    Annotated[float, "training_acc"],\n]:\n    """Train a sklearn SVC classifier."""\n\n    model = SVC(gamma=gamma)\n    model.fit(X_train.to_numpy(), y_train.to_numpy())\n\n    train_acc = model.score(X_train.to_numpy(), y_train.to_numpy())\n    print(f"Train accuracy: {train_acc}")\n\n    return model, train_acc\n', start_time=datetime.datetime(2023, 7, 23, 10, 9, 7, 216683), end_time=datetime.datetime(2023, 7, 23, 10, 9, 7, 659316), inputs={'X_train': ArtifactResponseModel(id=UUID('3884e7d4-c661-423f-8de7-8ad5b8afbebb'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 194458), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 194460), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id ...

# %%
pipeline_model.runs[0].steps["training_data_loader"].outputs
# Out:
# {'y_test': ArtifactResponseModel(id=UUID('10cde501-15fe-4411-b031-2b8c8031aaa7'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 970446), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 970448), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='y_test', artifact_store_id=UUID('44a654dc-70ad-4a31-91f7-1c6fb1c59f83'), type=<ArtifactType.DATA: 'DataArtifact'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/y_test/4e1a0d21-03e8-4e73-9cba-23773dd4cb14', materializer=Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>), data_type=Source(module='pandas.core.series', attribute='Series', type=<SourceType.DISTRIBUTION_PACKAGE: 'distribution_package'>, version='2.0.3', package_name='pandas'), visualizations=[VisualizationModel(type=<VisualizationType.CSV: 'csv'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/y_test/4e1a0d21-03e8-4e73-9cba-23773dd4cb14/describe.csv')], producer_step_run_id=UUID('4e1a0d21-03e8-4e73-9cba-23773dd4cb14'), metadata={'storage_size': RunMetadataResponseModel(id=UUID('4c140bbb-136b-4c8e-a2a8-74970aeccefb'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 987304), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 987305), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), pipeline_run_id=None, step_run_id=None, artifact_id=UUID('10cde501-15fe-4411-b031-2b8c8031aaa7'), stack_component_id=None, key='storage_size', value='2532', type='StorageSize'), 'shape': RunMetadataResponseModel(id=UUID('7521cb75-8668-4acf-a687-d89293ec6b8c'), created=datetime.datetime(2023, 7, 23, 10, 9, 7, 2541), updated=datetime.datetime(2023, 7, 23, 10, 9, 7, 2542), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'> ...
#  'X_train': ArtifactResponseModel(id=UUID('3884e7d4-c661-423f-8de7-8ad5b8afbebb'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 194458), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 194460), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='X_train', artifact_store_id=UUID('44a654dc-70ad-4a31-91f7-1c6fb1c59f83'), type=<ArtifactType.DATA: 'DataArtifact'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/X_train/4e1a0d21-03e8-4e73-9cba-23773dd4cb14', materializer=Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>), data_type=Source(module='pandas.core.frame', attribute='DataFrame', type=<SourceType.DISTRIBUTION_PACKAGE: 'distribution_package'>, version='2.0.3', package_name='pandas'), visualizations=[VisualizationModel(type=<VisualizationType.CSV: 'csv'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/X_train/4e1a0d21-03e8-4e73-9cba-23773dd4cb14/describe.csv')], producer_step_run_id=UUID('4e1a0d21-03e8-4e73-9cba-23773dd4cb14'), metadata={'storage_size': RunMetadataResponseModel(id=UUID('de9e6ed6-3409-498e-875a-5b9d183e26a2'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 211476), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 211477), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), pipeline_run_id=None, step_run_id=None, artifact_id=UUID('3884e7d4-c661-423f-8de7-8ad5b8afbebb'), stack_component_id=None, key='storage_size', value='6150', type='StorageSize'), 'shape': RunMetadataResponseModel(id=UUID('8b6651f7-dd8b-4d1e-8e9e-9587abaa3422'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 226610), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 226611), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE ...
#  'X_test': ArtifactResponseModel(id=UUID('48ba67e8-9f88-42a1-8281-f1a674bf7a4b'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 449047), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 449048), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='X_test', artifact_store_id=UUID('44a654dc-70ad-4a31-91f7-1c6fb1c59f83'), type=<ArtifactType.DATA: 'DataArtifact'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/X_test/4e1a0d21-03e8-4e73-9cba-23773dd4cb14', materializer=Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>), data_type=Source(module='pandas.core.frame', attribute='DataFrame', type=<SourceType.DISTRIBUTION_PACKAGE: 'distribution_package'>, version='2.0.3', package_name='pandas'), visualizations=[VisualizationModel(type=<VisualizationType.CSV: 'csv'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/X_test/4e1a0d21-03e8-4e73-9cba-23773dd4cb14/describe.csv')], producer_step_run_id=UUID('4e1a0d21-03e8-4e73-9cba-23773dd4cb14'), metadata={'storage_size': RunMetadataResponseModel(id=UUID('6f98458d-25f7-4248-a187-952a37ca5e05'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 468923), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 468926), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), pipeline_run_id=None, step_run_id=None, artifact_id=UUID('48ba67e8-9f88-42a1-8281-f1a674bf7a4b'), stack_component_id=None, key='storage_size', value='5495', type='StorageSize'), 'shape': RunMetadataResponseModel(id=UUID('809e49fc-67da-439e-825d-57e29b156152'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 483426), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 483427), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'w ...
#  'y_train': ArtifactResponseModel(id=UUID('ebf60981-e5b1-4332-a46b-1f992a099f31'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 682707), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 682709), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), name='y_train', artifact_store_id=UUID('44a654dc-70ad-4a31-91f7-1c6fb1c59f83'), type=<ArtifactType.DATA: 'DataArtifact'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/y_train/4e1a0d21-03e8-4e73-9cba-23773dd4cb14', materializer=Source(module='zenml.materializers.pandas_materializer', attribute='PandasMaterializer', type=<SourceType.INTERNAL: 'internal'>), data_type=Source(module='pandas.core.series', attribute='Series', type=<SourceType.DISTRIBUTION_PACKAGE: 'distribution_package'>, version='2.0.3', package_name='pandas'), visualizations=[VisualizationModel(type=<VisualizationType.CSV: 'csv'>, uri='/home/olawale/.config/zenml/local_stores/44a654dc-70ad-4a31-91f7-1c6fb1c59f83/training_data_loader/y_train/4e1a0d21-03e8-4e73-9cba-23773dd4cb14/describe.csv')], producer_step_run_id=UUID('4e1a0d21-03e8-4e73-9cba-23773dd4cb14'), metadata={'storage_size': RunMetadataResponseModel(id=UUID('528bd51b-c214-48dd-ac95-94ee4d512b6d'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 700732), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 700734), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), pipeline_run_id=None, step_run_id=None, artifact_id=UUID('ebf60981-e5b1-4332-a46b-1f992a099f31'), stack_component_id=None, key='storage_size', value='2797', type='StorageSize'), 'shape': RunMetadataResponseModel(id=UUID('14454100-872c-4719-a838-943ea2250bd3'), created=datetime.datetime(2023, 7, 23, 10, 9, 6, 715600), updated=datetime.datetime(2023, 7, 23, 10, 9, 6, 715601), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE:  ...

# %%
output_torch_model = pipeline_model.runs[0].steps["svc_trainer"].outputs["trained_model"].load()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_164215/924698609.py:1 in <module>                                                 │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_164215/924698609.py'                        │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/models/ar │
# │ tifact_models.py:117 in load                                                                     │
# │                                                                                                  │
# │   114 │   │   """                                                                                │
# │   115 │   │   from zenml.utils.artifact_utils import load_artifact                               │
# │   116 │   │                                                                                      │
# │ ❱ 117 │   │   return load_artifact(self)                                                         │
# │   118 │                                                                                          │
# │   119 │   def read(self) -> Any:                                                                 │
# │   120 │   │   """(Deprecated) Materializes (loads) the data stored in this artifact.             │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/utils/art │
# │ ifact_utils.py:131 in load_artifact                                                              │
# │                                                                                                  │
# │   128 │   │   │   │   component_type=StackComponentType.ARTIFACT_STORE,                          │
# │   129 │   │   │   │   name_id_or_prefix=artifact.artifact_store_id,                              │
# │   130 │   │   │   )                                                                              │
# │ ❱ 131 │   │   │   _ = StackComponent.from_model(artifact_store_model)                            │
# │   132 │   │   │   artifact_store_loaded = True                                                   │
# │   133 │   │   except KeyError:                                                                   │
# │   134 │   │   │   pass                                                                           │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/stack/sta │
# │ ck_component.py:391 in from_model                                                                │
# │                                                                                                  │
# │   388 │   │   try:                                                                               │
# │   389 │   │   │   from zenml.stack import Flavor                                                 │
# │   390 │   │   │                                                                                  │
# │ ❱ 391 │   │   │   flavor = Flavor.from_model(flavor_model)                                       │
# │   392 │   │   except (ModuleNotFoundError, ImportError, NotImplementedError) as err:             │
# │   393 │   │   │   raise ImportError(                                                             │
# │   394 │   │   │   │   f"Couldn't import flavor {flavor_model.name}: {err}"                       │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/stack/fla │
# │ vor.py:132 in from_model                                                                         │
# │                                                                                                  │
# │   129 │   │   Returns:                                                                           │
# │   130 │   │   │   The loaded flavor.                                                             │
# │   131 │   │   """                                                                                │
# │ ❱ 132 │   │   flavor = source_utils.load(flavor_model.source)()                                  │
# │   133 │   │   return cast(Flavor, flavor)                                                        │
# │   134 │                                                                                          │
# │   135 │   def to_model(                                                                          │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/utils/sou │
# │ rce_utils.py:93 in load                                                                          │
# │                                                                                                  │
# │    90 │   elif source.type in {SourceType.USER, SourceType.UNKNOWN}:                             │
# │    91 │   │   # Unknown source might also refer to a user file, include source                   │
# │    92 │   │   # root in python path just to be sure                                              │
# │ ❱  93 │   │   import_root = get_source_root()                                                    │
# │    94 │                                                                                          │
# │    95 │   module = _load_module(module_name=source.module, import_root=import_root)              │
# │    96                                                                                            │
# │                                                                                                  │
# │ /home/olawale/Desktop/PROJECTS/OOD/mlops-zenML/.venv/lib/python3.9/site-packages/zenml/utils/sou │
# │ rce_utils.py:229 in get_source_root                                                              │
# │                                                                                                  │
# │   226 │   │   )                                                                                  │
# │   227 │                                                                                          │
# │   228 │   if not hasattr(main_module, "__file__") or not main_module.__file__:                   │
# │ ❱ 229 │   │   raise RuntimeError(                                                                │
# │   230 │   │   │   "Unable to determine source root because the main module does not "            │
# │   231 │   │   │   "have an associated file. This could be because you're running in "            │
# │   232 │   │   │   "an interactive Python environment."                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Unable to determine source root because the main module does not have an associated file. This could
# be because you're running in an interactive Python environment.

# %%
pipeline_model.runs[0].steps["svc_trainer"].outputs["trained_model"].metadata
# Out:
# {'storage_size': RunMetadataResponseModel(id=UUID('07c6e161-67f7-4a0c-91b7-1ccc9dcaaef5'), created=datetime.datetime(2023, 7, 23, 10, 9, 7, 479446), updated=datetime.datetime(2023, 7, 23, 10, 9, 7, 479448), user=UserResponseModel(id=UUID('e7ece4b5-723e-4da4-be79-dfa7fd716705'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 737843), updated=datetime.datetime(2023, 7, 22, 15, 52, 34, 746723), name='default', full_name='', email_opted_in=True, hub_token=None, active=True, activation_token=None, teams=[], roles=[RoleResponseModel(id=UUID('808dc440-ecb9-4c31-83c9-7bc73bef032b'), created=datetime.datetime(2023, 7, 22, 15, 49, 19, 927002), updated=datetime.datetime(2023, 7, 22, 15, 49, 19, 927004), name='admin', permissions={<PermissionType.READ: 'read'>, <PermissionType.WRITE: 'write'>, <PermissionType.ME: 'me'>})], email=None), workspace=WorkspaceResponseModel(id=UUID('16d21198-4608-42dd-bfcd-beb2145df6f3'), created=datetime.datetime(2023, 7, 22, 15, 49, 21, 353214), updated=datetime.datetime(2023, 7, 22, 15, 49, 21, 353216), name='default', description=''), pipeline_run_id=None, step_run_id=None, artifact_id=UUID('f7ee4207-83ad-497d-a3a7-f07bfe46cd50'), stack_component_id=None, key='storage_size', value='7294', type='StorageSize')}

# %%
pipeline_model.runs[0].steps["svc_trainer"].outputs["trained_model"].visualize()
